# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_path = 'Results/0022.dat'
results = pd.read_csv(results_path)
results.head()

# %%
results.loc[:,['Magnetization','Temperature']].plot.line(y='Magnetization', x='Temperature')
plt.show()
