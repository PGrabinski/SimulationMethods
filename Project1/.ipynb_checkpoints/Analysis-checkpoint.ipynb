# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
path = 'Results'
print(os.listdir(path))
# Out:
# ['2319.dat', '20111144.csv', '19111210.dat', '0022.dat', '1542710837.5901477.csv', '1542710959.2313738.csv', '20110846.dat', '0000', '19111144.dat', '1542715808.8769522.csv', '1542715931.0855222.csv', '1542715694.7917862.csv', '1542714741.5753446.csv', 'int13122.csv', '1542712221.236584.csv', '0046.dat']

# %%
results_path = os.path.join(path, 'int1820.csv')
results = pd.read_csv(results_path, names=['Energy', 'dE', 'Magnetization', 'Heat', 'dC', 'Temperature'])
results.head()
# Out:
#    Energy       dE  Magnetization  Heat   dC  Temperature
# 0    -2.0  3.19374            1.0   0.0  0.0         0.05
# 1    -2.0  3.19374            1.0   0.0  0.0         0.10
# 2    -2.0  3.19374            1.0   0.0  0.0         0.15
# 3    -2.0  3.19374            1.0   0.0  0.0         0.20
# 4    -2.0  3.19374            1.0   0.0  0.0         0.25

# %%
results.plot.line(y='Magnetization', x='Temperature')
plt.show()

# %%
results.plot.line(y='Energy', x='Temperature')
plt.show()

# %%
results.plot.line(y='dE', x='Temperature')
plt.show()

# %%
results.plot.line(y='Heat', x='Temperature')
plt.show()

# %%
results.plot.line(y='dC', x='Temperature')
plt.show()

# %%
different_rngs = pd.read_csv('Results/1542733753.2022023.csv')

# %%
different_rngs.head()
# Out:
#      RNG   Energy  EnergyDev  Magnetization     Heat  HeatDev  Temperature
# 0     mt -1.45233   0.073865       0.712079  1.50341  1.41313      2.26918
# 1  rnlx0 -1.45235   0.073868       0.712216  1.51091  1.42016      2.26918
# 2   r250 -1.45334   0.073904       0.714127  1.47084  1.37793      2.26918
